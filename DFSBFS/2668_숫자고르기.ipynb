# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-03-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.16.17.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202023-03-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%2012.16.17.png)

# %% [markdown]
# ![IMG_60AA06F15C56-1.jpeg](attachment:IMG_60AA06F15C56-1.jpeg)

# %% [markdown]
# ## 접근
# 양방향 연결되어 있는 애들을 찾으면되겠다!
# 예를들어, 1,3이 있따면 3,1이 있는지 찾고 있따면 1,3을 answer에 추가.
# 두번째는 첫째줄 원소와 둘째줄 원소가 같다면 해당 숫자를 answer에 추가.
# answer출력.

# %% [markdown]
# ## 해결방법
# - 입력값을 이차원 리스트로 받아온다.
# [[1,2],[2,1],[3,1],[4,5],[5,5],[6,4],[7,6]]
# graph[1]부터 탐색한다.
# if graph[1] == graph[i]:
#     answer.append(graph[i])

# %%
n = int(input())
graph = [[] for _ in range(n+1)]
for i in range(1,n+1):
    a = i
    b = int(input())
    graph[i].append(a)
    graph[i].append(b)
    graph = set(graph)
# Out:
# 7
# 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 8
#       6 graph[i].append(a)
#       7 graph[i].append(b)
# ----> 8 graph = set(graph)
#
# TypeError: unhashable type: 'list'

# %%
print(graph)
# Out:
# [[], [1, 3], [2, 1], [3, 1], [4, 5], [5, 5], [6, 4], [7, 6]]

# %%
x = []
new_graph = []
answer = []



def dfs(node):
    visit[node] = True
    
    
    
for row in graph :
    if graph[a][b] == graph[b][a]:
        answer.append(graph[a],graph[b])
    if graph
            
            
            
# print(len(answer))
# for i in answer:
#     print(answer[i]) # 중복되는 거 빼고

    
    
    
    
    
# dfs(1)
# Out:
# []

# %%
for i in range(1,n+1):
    visit = [False]*(n+1)

# %%
print(visit)
# Out:
# [False, False, False, False, False, False, False, False]

# %%
bottom = [[] for _ in range(n+1)]
cycles = []
for i in range(1, n+1):
    bottom[i].append(int(input()))
# Out:
# 3
# 1
# 1
# 5
# 5
# 4
# 6

# %%
print(bottom)
# Out:
# [[], [3], [1], [1], [5], [5], [4], [6]]

# %% [markdown]
# 이미 방문한 노드가 또 다시 등장한다 -> 사이클이 존재한다
# 이렇게 사이클이 생기면 Result리스트에 사이클을 구성하는 노드들을 모두 추가한다.
